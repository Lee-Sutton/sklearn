# %% [markdown]
# # Logistic Regression
# ## Logistic regression seeks to:
# - model the probability of an event occuring depending on the value of the independent variables
# - We can use this to classify the observations
#
# ## Coding demo
# - We will be using the scikit learn library to classify flower types using the iris flower dataset. More information on the dataset can be found here: https://en.wikipedia.org/wiki/Iris_flower_data_set
# - In the first example we will use logistic regression to build a simple classifer using only the sepal length and sepal width
# - Links to more information on the logistic regression classifier
#     - Linear models: http://scikit-learn.org/stable/modules/linear_model.html
#     - Logistic Regression http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
# Visualize funtion based on the input classifier
def visualize(clf, X, Y):
    # Step size
    h = 0.02
    
    # we create an instance of Neighbours Classifier and fit the data.
    clf.fit(X, Y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure(1, figsize=(4, 3))
    plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')

    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())

    plt.show()

# %%
# Let's start by creating a simple logisitic regression model to classify data
# from the iris dataset
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.metrics import accuracy_score
# %matplotlib notebook

# Start by loading the dataset
iris = datasets.load_iris()

# Let's only load the first 2 features so we can visualize it at the end
X = iris.data[:, :2]
Y = iris.target

# Now for the logistic classification
clf = LogisticRegression()
clf.fit(X,Y)

# Predict the output using the classifier
y_pred = clf.predict(X)

# Test the accuracy
print accuracy_score(Y, y_pred)
visualize(clf, X, Y)
# Out:
# 0.766666666667
# <img src="data:image/png;base64,..." width="400">

# %%
# Now let's try splitting testing training data
from sklearn.model_selection import train_test_split
# for those who have not updated sklearn recently it will be in the cross_validation module
# ie. if you try to run the line above and you get the following error:
# ImportError: No module named model_selection
# try the following line:
# from sklearn.cross_validation import train_test_split

# X = iris.data

# Let's split the data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

# Now let's re-train the model on the training data
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict the output and test accuracy
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7

# %% [markdown]
# # Support Vector Machines
# - In this section we will examine the iris dataset using support vector machines for classifcation

# %%
# Start by importing the support vector machine classifier
from sklearn.svm import SVC

# Now for the logistic classification
clf = SVC(kernel='rbf')
clf.fit(X_train, y_train)

# Predict the output using the classifier
y_pred = clf.predict(X_test)

# Test the accuracy
print accuracy_score(y_test, y_pred)
visualize(clf, X, Y)
# Out:
# 0.86
